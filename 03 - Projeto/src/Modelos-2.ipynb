# %%
import pandas as pd
import gc #garbage collector

pd.set_option('display.max_columns', None)
#pd.reset_option('display.max_rows')
pd.set_option('display.max_rows', 20)  # ao invés de none pode por INT do limite
#pd.set_option('display.max_colwidth', None)

df = pd.read_csv('../data/df_dados_integrados_1onda.csv', low_memory=False)

# %%
from linearmodels import PanelOLS
ef=False
te=False
cr=False

ridf = df.set_index(['CityName','Date'])
#print(PanelOLS(ridf['StringencyIndexForDisplay'], ridf['deaths']).fit())
vec = {'C1_School closing' ,
'C2_Workplace closing' ,
'C3_Cancel public events',
'C4_Restrictions on gatherings',
'C5_Close public transport',
'C6_Stay at home requirements',
'C7_Restrictions on internal movement',
'C8_International travel controls',
'H1_Public information campaigns'}

pooledOlsMP = {}
vals = {5,10,15,20,25,30,35,37,40,45,50,55,60,90,120}
for val in vals:
    pooledOlsMP['MortePonderadaP100kLag+' + str(val)] =  PanelOLS(ridf['MortePonderadaP100kLag+' + str(val)], ridf[vec],entity_effects=ef,time_effects=te, check_rank=cr,drop_absorbed=True).fit()
# Out:
# C:\Users\mabaw\AppData\Local\Temp\ipykernel_25020\1498702855.py:21: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   pooledOlsMP['MortePonderadaP100kLag+' + str(val)] =  PanelOLS(ridf['MortePonderadaP100kLag+' + str(val)], ridf[vec],entity_effects=ef,time_effects=te, check_rank=cr,drop_absorbed=True).fit()
# c:\Python310\lib\site-packages\linearmodels\panel\model.py:1184: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   super().__init__(dependent, exog, weights=weights, check_rank=check_rank)
# C:\Users\mabaw\AppData\Local\Temp\ipykernel_25020\1498702855.py:21: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   pooledOlsMP['MortePonderadaP100kLag+' + str(val)] =  PanelOLS(ridf['MortePonderadaP100kLag+' + str(val)], ridf[vec],entity_effects=ef,time_effects=te, check_rank=cr,drop_absorbed=True).fit()
# ...
